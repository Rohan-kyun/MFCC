# %% [markdown]
# #This is a Python Code to Train and Test the Labelled Data using Random Forest and to Predict the 115 MFCC.csv files.
# #Note : This Code requires the Labelled mp3 Data Files and MFCC.csv files to be dowloaded, preferably on your Google Drive.

# %% [markdown]
# Importing the required Libraries

# %%
from zipfile import ZipFile
import os
import shutil
import numpy as np
import librosa
import random
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import joblib
import pandas as pd

# %% [markdown]
# Mounting to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Extracting MFCC.csv files. In my case 01-MFCC.zip is the folder in my Drive where all 115 MFCC.csv files are present

# %%
with ZipFile('drive/MyDrive/01-MFCC.zip', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall()

# %% [markdown]
# Copying all the songs to /content

# %%
# Define the base path to your songs in Google Drive
drive_path = '/content/drive/MyDrive/Project_Files'
songs = [
    "BhavGeet_1.mp3", "BhavGeet_2.mp3", "BhavGeet_3.mp3", "BhavGeet_4.mp3","BhavGeet_5.mp3", "BhavGeet_6.mp3", "BhavGeet_7.mp3", "BhavGeet_8.mp3","BhavGeet_9.mp3", "BhavGeet_10.mp3", "BhavGeet_11.mp3", "BhavGeet_12.mp3","BhavGeet_13.mp3", "BhavGeet_14.mp3", "BhavGeet_15.mp3","BhavGeet_16.mp3", "BhavGeet_17.mp3", "BhavGeet_18.mp3","BhavGeet_19.mp3", "BhavGeet_20.mp3", "BhavGeet_21.mp3", "BhavGeet_22.mp3",
    "Lavni_1.mp3", "Lavni_2.mp3", "Lavni_3.mp3", "Lavni_4.mp3","Lavni_5.mp3","Lavni_6.mp3","Lavni_7.mp3", "Lavni_8.mp3", "Lavni_9.mp3","Lavni_10.mp3","Lavni_11.mp3", "Lavni_12.mp3", "Lavni_13.mp3", "Lavni_14.mp3","Lavni_15.mp3","Lavni_16.mp3","Lavni_17.mp3", "Lavni_18.mp3", "Lavni_19.mp3","Lavni_20.mp3","Lavni_21.mp3", "Lavni_22.mp3", "Lavni_23.mp3",
    "AshaBhosale_1.mp3", "AshaBhosale_2.mp3", "AshaBhosale_3.mp3", "AshaBhosale_4.mp3","AshaBhosale_5.mp3","AshaBhosale_6.mp3","AshaBhosale_7.mp3", "AshaBhosale_8.mp3", "AshaBhosale_9.mp3","AshaBhosale_10.mp3","AshaBhosale_11.mp3", "AshaBhosale_12.mp3","AshaBhosale_13.mp3", "AshaBhosale_14.mp3", "AshaBhosale_15.mp3","AshaBhosale_16.mp3","AshaBhosale_17.mp3", "AshaBhosale_18.mp3", "AshaBhosale_19.mp3","AshaBhosale_20.mp3","AshaBhosale_21.mp3", "AshaBhosale_22.mp3",
    "Kishor_1.mp3", "Kishor_2.mp3", "Kishor_3.mp3", "Kishor_4.mp3", "Kishor_5.mp3", "Kishor_6.mp3","Kishor_7.mp3", "Kishor_8.mp3", "Kishor_9.mp3","Kishor_10.mp3","Kishor_11.mp3", "Kishor_12.mp3","Kishor_13.mp3", "Kishor_14.mp3", "Kishor_15.mp3","Kishor_16.mp3","Kishor_17.mp3", "Kishor_18.mp3", "Kishor_19.mp3","Kishor_20.mp3","Kishor_21.mp3", "Kishor_22.mp3",
    "MJ_1.mp3", "MJ_2.mp3", "MJ_3.mp3", "MJ_4.mp3", "MJ_5.mp3", "MJ_6.mp3","MJ_7.mp3", "MJ_8.mp3", "MJ_9.mp3","MJ_10.mp3","MJ_11.mp3", "MJ_12.mp3","MJ_13.mp3", "MJ_14.mp3", "MJ_15.mp3", "MJ_16.mp3","MJ_17.mp3", "MJ_18.mp3", "MJ_19.mp3","MJ_20.mp3","MJ_21.mp3", "MJ_22.mp3"

]

# Copy each song to the current working directory
for song in songs:
    src = os.path.join(drive_path, song)
    dst = os.path.join('/content', song)
    shutil.copy(src, dst)
    print(f"Copied {song} to /content")
# Out:
# Copied BhavGeet_1.mp3 to /content
# Copied BhavGeet_2.mp3 to /content
# Copied BhavGeet_3.mp3 to /content
# Copied BhavGeet_4.mp3 to /content
# Copied BhavGeet_5.mp3 to /content
# Copied BhavGeet_6.mp3 to /content
# Copied BhavGeet_7.mp3 to /content
# Copied BhavGeet_8.mp3 to /content
# Copied BhavGeet_9.mp3 to /content
# Copied BhavGeet_10.mp3 to /content
# Copied BhavGeet_11.mp3 to /content
# Copied BhavGeet_12.mp3 to /content
# Copied BhavGeet_13.mp3 to /content
# Copied BhavGeet_14.mp3 to /content
# Copied BhavGeet_15.mp3 to /content
# Copied BhavGeet_16.mp3 to /content
# Copied BhavGeet_17.mp3 to /content
# Copied BhavGeet_18.mp3 to /content
# Copied BhavGeet_19.mp3 to /content
# Copied BhavGeet_20.mp3 to /content
# Copied BhavGeet_21.mp3 to /content
# Copied BhavGeet_22.mp3 to /content
# Copied Lavni_1.mp3 to /content
# Copied Lavni_2.mp3 to /content
# Copied Lavni_3.mp3 to /content
# Copied Lavni_4.mp3 to /content
# Copied Lavni_5.mp3 to /content
# Copied Lavni_6.mp3 to /content
# Copied Lavni_7.mp3 to /content
# Copied Lavni_8.mp3 to /content
# Copied Lavni_9.mp3 to /content
# Copied Lavni_10.mp3 to /content
# Copied Lavni_11.mp3 to /content
# Copied Lavni_12.mp3 to /content
# Copied Lavni_13.mp3 to /content
# Copied Lavni_14.mp3 to /content
# Copied Lavni_15.mp3 to /content
# Copied Lavni_16.mp3 to /content
# Copied Lavni_17.mp3 to /content
# Copied Lavni_18.mp3 to /content
# Copied Lavni_19.mp3 to /content
# Copied Lavni_20.mp3 to /content
# Copied Lavni_21.mp3 to /content
# Copied Lavni_22.mp3 to /content
# Copied Lavni_23.mp3 to /content
# Copied AshaBhosale_1.mp3 to /content
# Copied AshaBhosale_2.mp3 to /content
# Copied AshaBhosale_3.mp3 to /content
# Copied AshaBhosale_4.mp3 to /content
# Copied AshaBhosale_5.mp3 to /content
# Copied AshaBhosale_6.mp3 to /content
# Copied AshaBhosale_7.mp3 to /content
# Copied AshaBhosale_8.mp3 to /content
# Copied AshaBhosale_9.mp3 to /content
# Copied AshaBhosale_10.mp3 to /content
# Copied AshaBhosale_11.mp3 to /content
# Copied AshaBhosale_12.mp3 to /content
# Copied AshaBhosale_13.mp3 to /content
# Copied AshaBhosale_14.mp3 to /content
# Copied AshaBhosale_15.mp3 to /content
# Copied AshaBhosale_16.mp3 to /content
# Copied AshaBhosale_17.mp3 to /content
# Copied AshaBhosale_18.mp3 to /content
# Copied AshaBhosale_19.mp3 to /content
# Copied AshaBhosale_20.mp3 to /content
# Copied AshaBhosale_21.mp3 to /content
# Copied AshaBhosale_22.mp3 to /content
# Copied Kishor_1.mp3 to /content
# Copied Kishor_2.mp3 to /content
# Copied Kishor_3.mp3 to /content
# Copied Kishor_4.mp3 to /content
# Copied Kishor_5.mp3 to /content
# Copied Kishor_6.mp3 to /content
# Copied Kishor_7.mp3 to /content
# Copied Kishor_8.mp3 to /content
# Copied Kishor_9.mp3 to /content
# Copied Kishor_10.mp3 to /content
# Copied Kishor_11.mp3 to /content
# Copied Kishor_12.mp3 to /content
# Copied Kishor_13.mp3 to /content
# Copied Kishor_14.mp3 to /content
# Copied Kishor_15.mp3 to /content
# Copied Kishor_16.mp3 to /content
# Copied Kishor_17.mp3 to /content
# Copied Kishor_18.mp3 to /content
# Copied Kishor_19.mp3 to /content
# Copied Kishor_20.mp3 to /content
# Copied Kishor_21.mp3 to /content
# Copied Kishor_22.mp3 to /content
# Copied MJ_1.mp3 to /content
# Copied MJ_2.mp3 to /content
# Copied MJ_3.mp3 to /content
# Copied MJ_4.mp3 to /content
# Copied MJ_5.mp3 to /content
# Copied MJ_6.mp3 to /content
# Copied MJ_7.mp3 to /content
# Copied MJ_8.mp3 to /content
# Copied MJ_9.mp3 to /content
# Copied MJ_10.mp3 to /content
# Copied MJ_11.mp3 to /content
# Copied MJ_12.mp3 to /content
# Copied MJ_13.mp3 to /content
# Copied MJ_14.mp3 to /content
# Copied MJ_15.mp3 to /content
# Copied MJ_16.mp3 to /content
# Copied MJ_17.mp3 to /content
# Copied MJ_18.mp3 to /content
# Copied MJ_19.mp3 to /content
# Copied MJ_20.mp3 to /content
# Copied MJ_21.mp3 to /content
# Copied MJ_22.mp3 to /content

# %% [markdown]
# PreProcessing Data

# %%
# Function to extract MFCC features using a sliding window approach and sample n_frames
def extract_and_sample_mfcc(file_path, n_mfcc=17, sr=44100, window_size= 60, hop_length=15, n_frames=3000):
    y, _ = librosa.load(file_path, sr=sr)
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)

    num_frames = mfccs.shape[1]
    output = []

    # Use a sliding window approach to form input features
    for i in range(0, num_frames - window_size + 1, hop_length):
        window = mfccs[:, i:i + window_size].T  # Shape: (window_size x n_mfcc)
        output.append(window)

    output = np.array(output)

    # If we have more than n_frames, sample randomly
    if len(output) > n_frames:
        idx = np.sort(np.random.choice(len(output), n_frames, replace=False))
        output = output[idx]

    return output.reshape(-1, n_mfcc * window_size)  # Flatten the windows for Random Forest input

# Define the categories and their songs (adjusted without MP4 confusion)
categories = {
    "Marathi_Bhav_Geet": [ "BhavGeet_1.mp3", "BhavGeet_2.mp3", "BhavGeet_3.mp3", "BhavGeet_4.mp3","BhavGeet_5.mp3", "BhavGeet_6.mp3", "BhavGeet_7.mp3", "BhavGeet_8.mp3","BhavGeet_9.mp3", "BhavGeet_10.mp3", "BhavGeet_11.mp3", "BhavGeet_12.mp3","BhavGeet_13.mp3", "BhavGeet_14.mp3", "BhavGeet_15.mp3","BhavGeet_16.mp3", "BhavGeet_17.mp3", "BhavGeet_18.mp3","BhavGeet_19.mp3", "BhavGeet_20.mp3", "BhavGeet_21.mp3", "BhavGeet_22.mp3"],
    "Marathi_Lavni": ["Lavni_1.mp3", "Lavni_2.mp3", "Lavni_3.mp3", "Lavni_4.mp3","Lavni_5.mp3","Lavni_6.mp3","Lavni_7.mp3", "Lavni_8.mp3", "Lavni_9.mp3","Lavni_10.mp3","Lavni_11.mp3", "Lavni_12.mp3", "Lavni_13.mp3", "Lavni_14.mp3","Lavni_15.mp3","Lavni_16.mp3","Lavni_17.mp3", "Lavni_18.mp3", "Lavni_19.mp3","Lavni_20.mp3","Lavni_21.mp3", "Lavni_22.mp3", "Lavni_23.mp3"],
    "Asha_Bhosale": ["AshaBhosale_1.mp3", "AshaBhosale_2.mp3", "AshaBhosale_3.mp3", "AshaBhosale_4.mp3","AshaBhosale_5.mp3","AshaBhosale_6.mp3","AshaBhosale_7.mp3", "AshaBhosale_8.mp3", "AshaBhosale_9.mp3","AshaBhosale_10.mp3","AshaBhosale_11.mp3", "AshaBhosale_12.mp3","AshaBhosale_13.mp3", "AshaBhosale_14.mp3", "AshaBhosale_15.mp3","AshaBhosale_16.mp3","AshaBhosale_17.mp3", "AshaBhosale_18.mp3", "AshaBhosale_19.mp3","AshaBhosale_20.mp3","AshaBhosale_21.mp3", "AshaBhosale_22.mp3"],
    "Kishor_Kumar": ["Kishor_1.mp3", "Kishor_2.mp3", "Kishor_3.mp3", "Kishor_4.mp3", "Kishor_5.mp3", "Kishor_6.mp3","Kishor_7.mp3", "Kishor_8.mp3", "Kishor_9.mp3","Kishor_10.mp3","Kishor_11.mp3", "Kishor_12.mp3","Kishor_13.mp3", "Kishor_14.mp3", "Kishor_15.mp3","Kishor_16.mp3","Kishor_17.mp3", "Kishor_18.mp3", "Kishor_19.mp3","Kishor_20.mp3","Kishor_21.mp3", "Kishor_22.mp3"],
    "Michael_Jackson": ["MJ_1.mp3", "MJ_2.mp3", "MJ_3.mp3", "MJ_4.mp3", "MJ_5.mp3", "MJ_6.mp3","MJ_7.mp3", "MJ_8.mp3", "MJ_9.mp3","MJ_10.mp3","MJ_11.mp3", "MJ_12.mp3","MJ_13.mp3", "MJ_14.mp3", "MJ_15.mp3", "MJ_16.mp3","MJ_17.mp3", "MJ_18.mp3", "MJ_19.mp3","MJ_20.mp3","MJ_21.mp3", "MJ_22.mp3"]

}

# %% [markdown]
# Splitting Training and Testing Data and feeding them to the Model and Training Model

# %%
# Initialize lists to store training and testing data and labels
X_train_rf = []
y_train_rf = []
X_test_rf = []
y_test_rf = []

# Process each category and extract features
for label_idx, (label_name, songs) in enumerate(categories.items()):
    # Randomly select 1 song for testing and use the rest for training
    test_songs = random.sample(songs, 2)
    train_songs = [song for song in songs if song not in test_songs]

    # Process test songs
    for song in test_songs:
        file_path = os.path.join('/content', song)  # Adjust path as needed for your environment
        print(f"Processing {song} for testing...")
        mfcc_windows = extract_and_sample_mfcc(file_path)
        X_test_rf.append(mfcc_windows)
        y_test_rf.append([label_idx] * len(mfcc_windows))  # Assign label to each window

    # Process train songs
    for song in train_songs:
        file_path = os.path.join('/content', song)  # Adjust path as needed for your environment
        print(f"Processing {song} for training...")
        mfcc_windows = extract_and_sample_mfcc(file_path)
        X_train_rf.append(mfcc_windows)
        y_train_rf.append([label_idx] * len(mfcc_windows))  # Assign label to each window

# Convert lists to NumPy arrays and reshape them appropriately for Random Forest input (samples x features)
X_train_rf = np.vstack(X_train_rf)  # Shape: (num_samples x flattened features)
y_train_rf = np.hstack(y_train_rf)

X_test_rf = np.vstack(X_test_rf)   # Shape: (num_samples x flattened features)
y_test_rf = np.hstack(y_test_rf)

# Normalize the data using StandardScaler
scaler_rf = StandardScaler()
X_train_rf_scaled = scaler_rf.fit_transform(X_train_rf)
X_test_rf_scaled = scaler_rf.transform(X_test_rf)

print("Training data shape:", X_train_rf_scaled.shape)
print("Testing data shape:", X_test_rf_scaled.shape)

# Build and train Random Forest classifier
rf_model = RandomForestClassifier(n_estimators=150)   # Using a forest of 100 trees
rf_model.fit(X_train_rf_scaled, y_train_rf)

# Make predictions on the test set
y_pred_rf = rf_model.predict(X_test_rf_scaled)
# Out:
# Processing BhavGeet_8.mp3 for testing...
# Processing BhavGeet_10.mp3 for testing...
# Processing BhavGeet_1.mp3 for training...
# Processing BhavGeet_2.mp3 for training...
# Processing BhavGeet_3.mp3 for training...
# Processing BhavGeet_4.mp3 for training...
# Processing BhavGeet_5.mp3 for training...
# Processing BhavGeet_6.mp3 for training...
# Processing BhavGeet_7.mp3 for training...
# Processing BhavGeet_9.mp3 for training...
# Processing BhavGeet_11.mp3 for training...
# Processing BhavGeet_12.mp3 for training...
# Processing BhavGeet_13.mp3 for training...
# Processing BhavGeet_14.mp3 for training...
# Processing BhavGeet_15.mp3 for training...
# Processing BhavGeet_16.mp3 for training...
# Processing BhavGeet_17.mp3 for training...
# Processing BhavGeet_18.mp3 for training...
# Processing BhavGeet_19.mp3 for training...
# Processing BhavGeet_20.mp3 for training...
# Processing BhavGeet_21.mp3 for training...
# Processing BhavGeet_22.mp3 for training...
# Processing Lavni_19.mp3 for testing...
# <ipython-input-5-954ae31eda9d>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sr)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing Lavni_22.mp3 for testing...
# Processing Lavni_1.mp3 for training...
# Processing Lavni_2.mp3 for training...
# Processing Lavni_3.mp3 for training...
# Processing Lavni_4.mp3 for training...
# Processing Lavni_5.mp3 for training...
# Processing Lavni_6.mp3 for training...
# Processing Lavni_7.mp3 for training...
# Processing Lavni_8.mp3 for training...
# Processing Lavni_9.mp3 for training...
# Processing Lavni_10.mp3 for training...
# Processing Lavni_11.mp3 for training...
# Processing Lavni_12.mp3 for training...
# Processing Lavni_13.mp3 for training...
# Processing Lavni_14.mp3 for training...
# Processing Lavni_15.mp3 for training...
# Processing Lavni_16.mp3 for training...
# Processing Lavni_17.mp3 for training...
# Processing Lavni_18.mp3 for training...
# Processing Lavni_20.mp3 for training...
# Processing Lavni_21.mp3 for training...
# Processing Lavni_23.mp3 for training...
# <ipython-input-5-954ae31eda9d>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sr)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing AshaBhosale_12.mp3 for testing...
# Processing AshaBhosale_3.mp3 for testing...
# Processing AshaBhosale_1.mp3 for training...
# Processing AshaBhosale_2.mp3 for training...
# Processing AshaBhosale_4.mp3 for training...
# Processing AshaBhosale_5.mp3 for training...
# Processing AshaBhosale_6.mp3 for training...
# Processing AshaBhosale_7.mp3 for training...
# Processing AshaBhosale_8.mp3 for training...
# Processing AshaBhosale_9.mp3 for training...
# Processing AshaBhosale_10.mp3 for training...
# Processing AshaBhosale_11.mp3 for training...
# Processing AshaBhosale_13.mp3 for training...
# Processing AshaBhosale_14.mp3 for training...
# Processing AshaBhosale_15.mp3 for training...
# Processing AshaBhosale_16.mp3 for training...
# Processing AshaBhosale_17.mp3 for training...
# Processing AshaBhosale_18.mp3 for training...
# Processing AshaBhosale_19.mp3 for training...
# Processing AshaBhosale_20.mp3 for training...
# Processing AshaBhosale_21.mp3 for training...
# Processing AshaBhosale_22.mp3 for training...
# Processing Kishor_21.mp3 for testing...
# Processing Kishor_20.mp3 for testing...
# Processing Kishor_1.mp3 for training...
# Processing Kishor_2.mp3 for training...
# Processing Kishor_3.mp3 for training...
# Processing Kishor_4.mp3 for training...
# Processing Kishor_5.mp3 for training...
# Processing Kishor_6.mp3 for training...
# Processing Kishor_7.mp3 for training...
# Processing Kishor_8.mp3 for training...
# Processing Kishor_9.mp3 for training...
# Processing Kishor_10.mp3 for training...
# Processing Kishor_11.mp3 for training...
# Processing Kishor_12.mp3 for training...
# Processing Kishor_13.mp3 for training...
# Processing Kishor_14.mp3 for training...
# Processing Kishor_15.mp3 for training...
# Processing Kishor_16.mp3 for training...
# Processing Kishor_17.mp3 for training...
# Processing Kishor_18.mp3 for training...
# Processing Kishor_19.mp3 for training...
# Processing Kishor_22.mp3 for training...
# Processing MJ_18.mp3 for testing...
# Processing MJ_6.mp3 for testing...
# Processing MJ_1.mp3 for training...
# Processing MJ_2.mp3 for training...
# Processing MJ_3.mp3 for training...
# Processing MJ_4.mp3 for training...
# Processing MJ_5.mp3 for training...
# Processing MJ_7.mp3 for training...
# Processing MJ_8.mp3 for training...
# Processing MJ_9.mp3 for training...
# Processing MJ_10.mp3 for training...
# Processing MJ_11.mp3 for training...
# Processing MJ_12.mp3 for training...
# Processing MJ_13.mp3 for training...
# Processing MJ_14.mp3 for training...
# Processing MJ_15.mp3 for training...
# Processing MJ_16.mp3 for training...
# Processing MJ_17.mp3 for training...
# Processing MJ_19.mp3 for training...
# Processing MJ_20.mp3 for training...
# Processing MJ_21.mp3 for training...
# Processing MJ_22.mp3 for training...
# Training data shape: (166188, 1020)
# Testing data shape: (18865, 1020)

# %% [markdown]
# Accuracy Check
# #Note, This Accuracy is excluding the National Anthem Category. National Anthem Category is seperately classified. if number of frames in the song < 12000 that song is directly classsified in National Anthem Category

# %%
# Evaluate accuracy on test set
test_accuracy_rf = accuracy_score(y_test_rf, y_pred_rf)
print(f"Test accuracy (Random Forest): {test_accuracy_rf}")
# Out:
# Test accuracy (Random Forest): 0.6934004770739465

# %% [markdown]
# Save the Model and Scaler

# %%
# Save the Random Forest model and scaler for future use
joblib.dump(rf_model, 'random_forest_model.pkl')
joblib.dump(scaler_rf, 'scaler_rf.pkl')
# Out:
# ['scaler_rf.pkl']

# %% [markdown]
# PreProcessing the MFCC.csv files

# %%
# Define categories for labeling predictions
categories = {
    "Marathi_Bhav_Geet": 0,
    "Marathi_Lavni": 1,
    "Asha_Bhosale": 2,
    "Kishor_Kumar": 3,
    "Michael_Jackson": 4
}
categories_list = list(categories.keys())
categories_list.insert(0, "Indian_National_Anthem")  # Add Indian National Anthem as category 0

# Function to apply sliding window on MFCC data from CSV files
def apply_sliding_window_and_sample(df, n_mfcc=17, window_size=60, hop_length=15, n_frames=3000):
    # df is already loaded with shape (20, num_frames)
    mfccs = df.values[:n_mfcc, :]  # Take top n_mfcc coefficients (first 17 rows)

    num_frames = mfccs.shape[1]
    output = []

    # Apply sliding window approach
    for i in range(0, num_frames - window_size + 1, hop_length):
        window = mfccs[:, i:i + window_size].T  # Shape: (window_size x n_mfcc)
        output.append(window)

    output = np.array(output)

    # If we have more than n_frames, sample randomly
    if len(output) > n_frames:
        idx = np.sort(np.random.choice(len(output), n_frames, replace=False))
        output = output[idx]

    return output.reshape(-1, n_mfcc * window_size)  # Flatten for model input

# %% [markdown]
# Copying MFCC.csv files to the /content

# %%
# Load MFCC CSV files from directory (adjust path as needed)
dataframes = {}
for filename in os.listdir('/content'):  # Adjust path accordingly
    if filename.endswith("-MFCC.csv"):
        try:
            df = pd.read_csv(os.path.join('/content', filename), header=None)
            dataframes[filename] = df
            print(f"Loaded {filename}: shape {df.shape}")
        except Exception as e:
            print(f"Error loading {filename}: {e}")
# Out:
# Loaded 48-MFCC.csv: shape (20, 28173)
# Loaded 88-MFCC.csv: shape (20, 25397)
# Loaded 03-MFCC.csv: shape (20, 24716)
# Loaded 54-MFCC.csv: shape (20, 22411)
# Loaded 65-MFCC.csv: shape (20, 20270)
# Loaded 67-MFCC.csv: shape (20, 9434)
# Loaded 110-MFCC.csv: shape (20, 24658)
# Loaded 26-MFCC.csv: shape (20, 17963)
# Loaded 24-MFCC.csv: shape (20, 25308)
# Loaded 37-MFCC.csv: shape (20, 16860)
# Loaded 103-MFCC.csv: shape (20, 34368)
# Loaded 87-MFCC.csv: shape (20, 9200)
# Loaded 09-MFCC.csv: shape (20, 27241)
# Loaded 91-MFCC.csv: shape (20, 20121)
# Loaded 93-MFCC.csv: shape (20, 19700)
# Loaded 13-MFCC.csv: shape (20, 33329)
# Loaded 75-MFCC.csv: shape (20, 6064)
# Loaded 66-MFCC.csv: shape (20, 10090)
# Loaded 31-MFCC.csv: shape (20, 10921)
# Loaded 60-MFCC.csv: shape (20, 22452)
# Loaded 10-MFCC.csv: shape (20, 30065)
# Loaded 07-MFCC.csv: shape (20, 18110)
# Loaded 104-MFCC.csv: shape (20, 34536)
# Loaded 20-MFCC.csv: shape (20, 25608)
# Loaded 42-MFCC.csv: shape (20, 18250)
# Loaded 08-MFCC.csv: shape (20, 22615)
# Loaded 85-MFCC.csv: shape (20, 18670)
# Loaded 47-MFCC.csv: shape (20, 25120)
# Loaded 53-MFCC.csv: shape (20, 28311)
# Loaded 115-MFCC.csv: shape (20, 25999)
# Loaded 64-MFCC.csv: shape (20, 17333)
# Loaded 77-MFCC.csv: shape (20, 18974)
# Loaded 28-MFCC.csv: shape (20, 21758)
# Loaded 27-MFCC.csv: shape (20, 9381)
# Loaded 80-MFCC.csv: shape (20, 32601)
# Loaded 105-MFCC.csv: shape (20, 13984)
# Loaded 111-MFCC.csv: shape (20, 24504)
# Loaded 36-MFCC.csv: shape (20, 33272)
# Loaded 38-MFCC.csv: shape (20, 32710)
# Loaded 04-MFCC.csv: shape (20, 19292)
# Loaded 113-MFCC.csv: shape (20, 28532)
# Loaded 69-MFCC.csv: shape (20, 29822)
# Loaded 32-MFCC.csv: shape (20, 22080)
# Loaded 11-MFCC.csv: shape (20, 19094)
# Loaded 101-MFCC.csv: shape (20, 18045)
# Loaded 21-MFCC.csv: shape (20, 30100)
# Loaded 106-MFCC.csv: shape (20, 24195)
# Loaded 62-MFCC.csv: shape (20, 17527)
# Loaded 61-MFCC.csv: shape (20, 9260)
# Loaded 95-MFCC.csv: shape (20, 9200)
# Loaded 18-MFCC.csv: shape (20, 16771)
# Loaded 112-MFCC.csv: shape (20, 17312)
# Loaded 97-MFCC.csv: shape (20, 24415)
# Loaded 45-MFCC.csv: shape (20, 35333)
# Loaded 29-MFCC.csv: shape (20, 18153)
# Loaded 68-MFCC.csv: shape (20, 16109)
# Loaded 46-MFCC.csv: shape (20, 22772)
# Loaded 49-MFCC.csv: shape (20, 19608)
# Loaded 41-MFCC.csv: shape (20, 17042)
# Loaded 107-MFCC.csv: shape (20, 11673)
# Loaded 30-MFCC.csv: shape (20, 24273)
# Loaded 05-MFCC.csv: shape (20, 21338)
# Loaded 34-MFCC.csv: shape (20, 40151)
# Loaded 50-MFCC.csv: shape (20, 25374)
# Loaded 96-MFCC.csv: shape (20, 27607)
# Loaded 14-MFCC.csv: shape (20, 16528)
# Loaded 90-MFCC.csv: shape (20, 9321)
# Loaded 114-MFCC.csv: shape (20, 30040)
# Loaded 22-MFCC.csv: shape (20, 19122)
# Loaded 98-MFCC.csv: shape (20, 28865)
# Loaded 51-MFCC.csv: shape (20, 17390)
# Loaded 63-MFCC.csv: shape (20, 17556)
# Loaded 83-MFCC.csv: shape (20, 26064)
# Loaded 56-MFCC.csv: shape (20, 18311)
# Loaded 81-MFCC.csv: shape (20, 9232)
# Loaded 35-MFCC.csv: shape (20, 9292)
# Loaded 01-MFCC.csv: shape (20, 9866)
# Loaded 19-MFCC.csv: shape (20, 20435)
# Loaded 12-MFCC.csv: shape (20, 30860)
# Loaded 92-MFCC.csv: shape (20, 22985)
# Loaded 57-MFCC.csv: shape (20, 21987)
# Loaded 76-MFCC.csv: shape (20, 19757)
# Loaded 39-MFCC.csv: shape (20, 17312)
# Loaded 02-MFCC.csv: shape (20, 9321)
# Loaded 16-MFCC.csv: shape (20, 11523)
# Loaded 71-MFCC.csv: shape (20, 35456)
# Loaded 17-MFCC.csv: shape (20, 10105)
# Loaded 74-MFCC.csv: shape (20, 22286)
# Loaded 06-MFCC.csv: shape (20, 31985)
# Loaded 40-MFCC.csv: shape (20, 29204)
# Loaded 58-MFCC.csv: shape (20, 18007)
# Loaded 108-MFCC.csv: shape (20, 9260)
# Loaded 44-MFCC.csv: shape (20, 36458)
# Loaded 84-MFCC.csv: shape (20, 17963)
# Loaded 89-MFCC.csv: shape (20, 33510)
# Loaded 99-MFCC.csv: shape (20, 20121)
# Loaded 102-MFCC.csv: shape (20, 18893)
# Loaded 70-MFCC.csv: shape (20, 27251)
# Loaded 25-MFCC.csv: shape (20, 18713)
# Loaded 23-MFCC.csv: shape (20, 32738)
# Loaded 79-MFCC.csv: shape (20, 23856)
# Loaded 82-MFCC.csv: shape (20, 27565)
# Loaded 72-MFCC.csv: shape (20, 19454)
# Loaded 73-MFCC.csv: shape (20, 20769)
# Loaded 59-MFCC.csv: shape (20, 13604)
# Loaded 100-MFCC.csv: shape (20, 15899)
# Loaded 109-MFCC.csv: shape (20, 27535)
# Loaded 15-MFCC.csv: shape (20, 31856)
# Loaded 43-MFCC.csv: shape (20, 15474)
# Loaded 94-MFCC.csv: shape (20, 30349)
# Loaded 52-MFCC.csv: shape (20, 28382)
# Loaded 33-MFCC.csv: shape (20, 18763)
# Loaded 78-MFCC.csv: shape (20, 21859)
# Loaded 55-MFCC.csv: shape (20, 21898)
# Loaded 86-MFCC.csv: shape (20, 31124)

# %% [markdown]
# Make predictions of MFCC.csv files using the saved Model and Scaler

# %%
# Process predictions on MFCC CSV files
song_predictions = {}

for filename, df in dataframes.items():
    print(f"Processing {filename}...")

    # Check if it's an Indian National Anthem based on frame count (columns < 12000)
    if df.shape[1] < 12000:
        song_predictions[filename] = "Indian_National_Anthem"
        print(f"Predicted category for {filename}: Indian_National_Anthem (based on frame count)")
        continue

    # Apply sliding window and sample frames (same as done during training)
    mfcc_windows = apply_sliding_window_and_sample(df)

    # Scale MFCC frames using the trained scaler
    mfcc_windows_scaled = scaler_rf.transform(mfcc_windows)

    # Predict category using Random Forest model for all windows and take majority vote
    predictions = rf_model.predict(mfcc_windows_scaled)

    # Use majority voting across all windows to decide final category for this song
    predicted_label_idx = np.bincount(predictions).argmax()

    predicted_category_name = categories_list[predicted_label_idx + 1]  # +1 to account for National Anthem at index 0

    song_predictions[filename] = predicted_category_name

    print(f"Predicted category for {filename}: {predicted_category_name}")

# Output final predictions for all songs
print("\nFinal Song Predictions:")
for filename, category in song_predictions.items():
    print(f"{filename}: {category}")
# Out:
# Processing 48-MFCC.csv...
# Predicted category for 48-MFCC.csv: Kishor_Kumar
# Processing 88-MFCC.csv...
# Predicted category for 88-MFCC.csv: Marathi_Lavni
# Processing 03-MFCC.csv...
# Predicted category for 03-MFCC.csv: Michael_Jackson
# Processing 54-MFCC.csv...
# Predicted category for 54-MFCC.csv: Marathi_Lavni
# Processing 65-MFCC.csv...
# Predicted category for 65-MFCC.csv: Marathi_Lavni
# Processing 67-MFCC.csv...
# Predicted category for 67-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 110-MFCC.csv...
# Predicted category for 110-MFCC.csv: Asha_Bhosale
# Processing 26-MFCC.csv...
# Predicted category for 26-MFCC.csv: Marathi_Bhav_Geet
# Processing 24-MFCC.csv...
# Predicted category for 24-MFCC.csv: Michael_Jackson
# Processing 37-MFCC.csv...
# Predicted category for 37-MFCC.csv: Michael_Jackson
# Processing 103-MFCC.csv...
# Predicted category for 103-MFCC.csv: Michael_Jackson
# Processing 87-MFCC.csv...
# Predicted category for 87-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 09-MFCC.csv...
# Predicted category for 09-MFCC.csv: Asha_Bhosale
# Processing 91-MFCC.csv...
# Predicted category for 91-MFCC.csv: Asha_Bhosale
# Processing 93-MFCC.csv...
# Predicted category for 93-MFCC.csv: Kishor_Kumar
# Processing 13-MFCC.csv...
# Predicted category for 13-MFCC.csv: Asha_Bhosale
# Processing 75-MFCC.csv...
# Predicted category for 75-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 66-MFCC.csv...
# Predicted category for 66-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 31-MFCC.csv...
# Predicted category for 31-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 60-MFCC.csv...
# Predicted category for 60-MFCC.csv: Kishor_Kumar
# Processing 10-MFCC.csv...
# Predicted category for 10-MFCC.csv: Marathi_Bhav_Geet
# Processing 07-MFCC.csv...
# Predicted category for 07-MFCC.csv: Asha_Bhosale
# Processing 104-MFCC.csv...
# Predicted category for 104-MFCC.csv: Michael_Jackson
# Processing 20-MFCC.csv...
# Predicted category for 20-MFCC.csv: Michael_Jackson
# Processing 42-MFCC.csv...
# Predicted category for 42-MFCC.csv: Marathi_Bhav_Geet
# Processing 08-MFCC.csv...
# Predicted category for 08-MFCC.csv: Michael_Jackson
# Processing 85-MFCC.csv...
# Predicted category for 85-MFCC.csv: Marathi_Lavni
# Processing 47-MFCC.csv...
# Predicted category for 47-MFCC.csv: Kishor_Kumar
# Processing 53-MFCC.csv...
# Predicted category for 53-MFCC.csv: Michael_Jackson
# Processing 115-MFCC.csv...
# Predicted category for 115-MFCC.csv: Marathi_Bhav_Geet
# Processing 64-MFCC.csv...
# Predicted category for 64-MFCC.csv: Asha_Bhosale
# Processing 77-MFCC.csv...
# Predicted category for 77-MFCC.csv: Asha_Bhosale
# Processing 28-MFCC.csv...
# Predicted category for 28-MFCC.csv: Asha_Bhosale
# Processing 27-MFCC.csv...
# Predicted category for 27-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 80-MFCC.csv...
# Predicted category for 80-MFCC.csv: Asha_Bhosale
# Processing 105-MFCC.csv...
# Predicted category for 105-MFCC.csv: Asha_Bhosale
# Processing 111-MFCC.csv...
# Predicted category for 111-MFCC.csv: Asha_Bhosale
# Processing 36-MFCC.csv...
# Predicted category for 36-MFCC.csv: Kishor_Kumar
# Processing 38-MFCC.csv...
# Predicted category for 38-MFCC.csv: Asha_Bhosale
# Processing 04-MFCC.csv...
# Predicted category for 04-MFCC.csv: Marathi_Lavni
# Processing 113-MFCC.csv...
# Predicted category for 113-MFCC.csv: Michael_Jackson
# Processing 69-MFCC.csv...
# Predicted category for 69-MFCC.csv: Michael_Jackson
# Processing 32-MFCC.csv...
# Predicted category for 32-MFCC.csv: Michael_Jackson
# Processing 11-MFCC.csv...
# Predicted category for 11-MFCC.csv: Marathi_Lavni
# Processing 101-MFCC.csv...
# Predicted category for 101-MFCC.csv: Asha_Bhosale
# Processing 21-MFCC.csv...
# Predicted category for 21-MFCC.csv: Marathi_Lavni
# Processing 106-MFCC.csv...
# Predicted category for 106-MFCC.csv: Marathi_Bhav_Geet
# Processing 62-MFCC.csv...
# Predicted category for 62-MFCC.csv: Marathi_Lavni
# Processing 61-MFCC.csv...
# Predicted category for 61-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 95-MFCC.csv...
# Predicted category for 95-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 18-MFCC.csv...
# Predicted category for 18-MFCC.csv: Asha_Bhosale
# Processing 112-MFCC.csv...
# Predicted category for 112-MFCC.csv: Asha_Bhosale
# Processing 97-MFCC.csv...
# Predicted category for 97-MFCC.csv: Asha_Bhosale
# Processing 45-MFCC.csv...
# Predicted category for 45-MFCC.csv: Michael_Jackson
# Processing 29-MFCC.csv...
# Predicted category for 29-MFCC.csv: Asha_Bhosale
# Processing 68-MFCC.csv...
# Predicted category for 68-MFCC.csv: Marathi_Lavni
# Processing 46-MFCC.csv...
# Predicted category for 46-MFCC.csv: Asha_Bhosale
# Processing 49-MFCC.csv...
# Predicted category for 49-MFCC.csv: Asha_Bhosale
# Processing 41-MFCC.csv...
# Predicted category for 41-MFCC.csv: Asha_Bhosale
# Processing 107-MFCC.csv...
# Predicted category for 107-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 30-MFCC.csv...
# Predicted category for 30-MFCC.csv: Marathi_Bhav_Geet
# Processing 05-MFCC.csv...
# Predicted category for 05-MFCC.csv: Asha_Bhosale
# Processing 34-MFCC.csv...
# Predicted category for 34-MFCC.csv: Marathi_Lavni
# Processing 50-MFCC.csv...
# Predicted category for 50-MFCC.csv: Asha_Bhosale
# Processing 96-MFCC.csv...
# Predicted category for 96-MFCC.csv: Asha_Bhosale
# Processing 14-MFCC.csv...
# Predicted category for 14-MFCC.csv: Marathi_Lavni
# Processing 90-MFCC.csv...
# Predicted category for 90-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 114-MFCC.csv...
# Predicted category for 114-MFCC.csv: Michael_Jackson
# Processing 22-MFCC.csv...
# Predicted category for 22-MFCC.csv: Marathi_Lavni
# Processing 98-MFCC.csv...
# Predicted category for 98-MFCC.csv: Michael_Jackson
# Processing 51-MFCC.csv...
# Predicted category for 51-MFCC.csv: Asha_Bhosale
# Processing 63-MFCC.csv...
# Predicted category for 63-MFCC.csv: Kishor_Kumar
# Processing 83-MFCC.csv...
# Predicted category for 83-MFCC.csv: Asha_Bhosale
# Processing 56-MFCC.csv...
# Predicted category for 56-MFCC.csv: Asha_Bhosale
# Processing 81-MFCC.csv...
# Predicted category for 81-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 35-MFCC.csv...
# Predicted category for 35-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 01-MFCC.csv...
# Predicted category for 01-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 19-MFCC.csv...
# Predicted category for 19-MFCC.csv: Marathi_Lavni
# Processing 12-MFCC.csv...
# Predicted category for 12-MFCC.csv: Marathi_Lavni
# Processing 92-MFCC.csv...
# Predicted category for 92-MFCC.csv: Asha_Bhosale
# Processing 57-MFCC.csv...
# Predicted category for 57-MFCC.csv: Michael_Jackson
# Processing 76-MFCC.csv...
# Predicted category for 76-MFCC.csv: Asha_Bhosale
# Processing 39-MFCC.csv...
# Predicted category for 39-MFCC.csv: Marathi_Lavni
# Processing 02-MFCC.csv...
# Predicted category for 02-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 16-MFCC.csv...
# Predicted category for 16-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 71-MFCC.csv...
# Predicted category for 71-MFCC.csv: Asha_Bhosale
# Processing 17-MFCC.csv...
# Predicted category for 17-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 74-MFCC.csv...
# Predicted category for 74-MFCC.csv: Marathi_Lavni
# Processing 06-MFCC.csv...
# Predicted category for 06-MFCC.csv: Marathi_Lavni
# Processing 40-MFCC.csv...
# Predicted category for 40-MFCC.csv: Kishor_Kumar
# Processing 58-MFCC.csv...
# Predicted category for 58-MFCC.csv: Michael_Jackson
# Processing 108-MFCC.csv...
# Predicted category for 108-MFCC.csv: Indian_National_Anthem (based on frame count)
# Processing 44-MFCC.csv...
# Predicted category for 44-MFCC.csv: Michael_Jackson
# Processing 84-MFCC.csv...
# Predicted category for 84-MFCC.csv: Asha_Bhosale
# Processing 89-MFCC.csv...
# Predicted category for 89-MFCC.csv: Asha_Bhosale
# Processing 99-MFCC.csv...
# Predicted category for 99-MFCC.csv: Asha_Bhosale
# Processing 102-MFCC.csv...
# Predicted category for 102-MFCC.csv: Asha_Bhosale
# Processing 70-MFCC.csv...
# Predicted category for 70-MFCC.csv: Marathi_Lavni
# Processing 25-MFCC.csv...
# Predicted category for 25-MFCC.csv: Asha_Bhosale
# Processing 23-MFCC.csv...
# Predicted category for 23-MFCC.csv: Asha_Bhosale
# Processing 79-MFCC.csv...
# Predicted category for 79-MFCC.csv: Asha_Bhosale
# Processing 82-MFCC.csv...
# Predicted category for 82-MFCC.csv: Asha_Bhosale
# Processing 72-MFCC.csv...
# Predicted category for 72-MFCC.csv: Marathi_Lavni
# Processing 73-MFCC.csv...
# Predicted category for 73-MFCC.csv: Marathi_Lavni
# Processing 59-MFCC.csv...
# Predicted category for 59-MFCC.csv: Kishor_Kumar
# Processing 100-MFCC.csv...
# Predicted category for 100-MFCC.csv: Asha_Bhosale
# Processing 109-MFCC.csv...
# Predicted category for 109-MFCC.csv: Marathi_Lavni
# Processing 15-MFCC.csv...
# Predicted category for 15-MFCC.csv: Marathi_Lavni
# Processing 43-MFCC.csv...
# Predicted category for 43-MFCC.csv: Marathi_Bhav_Geet
# Processing 94-MFCC.csv...
# Predicted category for 94-MFCC.csv: Asha_Bhosale
# Processing 52-MFCC.csv...
# Predicted category for 52-MFCC.csv: Marathi_Lavni
# Processing 33-MFCC.csv...
# Predicted category for 33-MFCC.csv: Asha_Bhosale
# Processing 78-MFCC.csv...
# Predicted category for 78-MFCC.csv: Michael_Jackson
# Processing 55-MFCC.csv...
# Predicted category for 55-MFCC.csv: Michael_Jackson
# Processing 86-MFCC.csv...
# Predicted category for 86-MFCC.csv: Michael_Jackson
#
# Final Song Predictions:
# 48-MFCC.csv: Kishor_Kumar
# 88-MFCC.csv: Marathi_Lavni
# 03-MFCC.csv: Michael_Jackson
# 54-MFCC.csv: Marathi_Lavni
# 65-MFCC.csv: Marathi_Lavni
# 67-MFCC.csv: Indian_National_Anthem
# 110-MFCC.csv: Asha_Bhosale
# 26-MFCC.csv: Marathi_Bhav_Geet
# 24-MFCC.csv: Michael_Jackson
# 37-MFCC.csv: Michael_Jackson
# 103-MFCC.csv: Michael_Jackson
# 87-MFCC.csv: Indian_National_Anthem
# 09-MFCC.csv: Asha_Bhosale
# 91-MFCC.csv: Asha_Bhosale
# 93-MFCC.csv: Kishor_Kumar
# 13-MFCC.csv: Asha_Bhosale
# 75-MFCC.csv: Indian_National_Anthem
# 66-MFCC.csv: Indian_National_Anthem
# 31-MFCC.csv: Indian_National_Anthem
# 60-MFCC.csv: Kishor_Kumar
# 10-MFCC.csv: Marathi_Bhav_Geet
# 07-MFCC.csv: Asha_Bhosale
# 104-MFCC.csv: Michael_Jackson
# 20-MFCC.csv: Michael_Jackson
# 42-MFCC.csv: Marathi_Bhav_Geet
# 08-MFCC.csv: Michael_Jackson
# 85-MFCC.csv: Marathi_Lavni
# 47-MFCC.csv: Kishor_Kumar
# 53-MFCC.csv: Michael_Jackson
# 115-MFCC.csv: Marathi_Bhav_Geet
# 64-MFCC.csv: Asha_Bhosale
# 77-MFCC.csv: Asha_Bhosale
# 28-MFCC.csv: Asha_Bhosale
# 27-MFCC.csv: Indian_National_Anthem
# 80-MFCC.csv: Asha_Bhosale
# 105-MFCC.csv: Asha_Bhosale
# 111-MFCC.csv: Asha_Bhosale
# 36-MFCC.csv: Kishor_Kumar
# 38-MFCC.csv: Asha_Bhosale
# 04-MFCC.csv: Marathi_Lavni
# 113-MFCC.csv: Michael_Jackson
# 69-MFCC.csv: Michael_Jackson
# 32-MFCC.csv: Michael_Jackson
# 11-MFCC.csv: Marathi_Lavni
# 101-MFCC.csv: Asha_Bhosale
# 21-MFCC.csv: Marathi_Lavni
# 106-MFCC.csv: Marathi_Bhav_Geet
# 62-MFCC.csv: Marathi_Lavni
# 61-MFCC.csv: Indian_National_Anthem
# 95-MFCC.csv: Indian_National_Anthem
# 18-MFCC.csv: Asha_Bhosale
# 112-MFCC.csv: Asha_Bhosale
# 97-MFCC.csv: Asha_Bhosale
# 45-MFCC.csv: Michael_Jackson
# 29-MFCC.csv: Asha_Bhosale
# 68-MFCC.csv: Marathi_Lavni
# 46-MFCC.csv: Asha_Bhosale
# 49-MFCC.csv: Asha_Bhosale
# 41-MFCC.csv: Asha_Bhosale
# 107-MFCC.csv: Indian_National_Anthem
# 30-MFCC.csv: Marathi_Bhav_Geet
# 05-MFCC.csv: Asha_Bhosale
# 34-MFCC.csv: Marathi_Lavni
# 50-MFCC.csv: Asha_Bhosale
# 96-MFCC.csv: Asha_Bhosale
# 14-MFCC.csv: Marathi_Lavni
# 90-MFCC.csv: Indian_National_Anthem
# 114-MFCC.csv: Michael_Jackson
# 22-MFCC.csv: Marathi_Lavni
# 98-MFCC.csv: Michael_Jackson
# 51-MFCC.csv: Asha_Bhosale
# 63-MFCC.csv: Kishor_Kumar
# 83-MFCC.csv: Asha_Bhosale
# 56-MFCC.csv: Asha_Bhosale
# 81-MFCC.csv: Indian_National_Anthem
# 35-MFCC.csv: Indian_National_Anthem
# 01-MFCC.csv: Indian_National_Anthem
# 19-MFCC.csv: Marathi_Lavni
# 12-MFCC.csv: Marathi_Lavni
# 92-MFCC.csv: Asha_Bhosale
# 57-MFCC.csv: Michael_Jackson
# 76-MFCC.csv: Asha_Bhosale
# 39-MFCC.csv: Marathi_Lavni
# 02-MFCC.csv: Indian_National_Anthem
# 16-MFCC.csv: Indian_National_Anthem
# 71-MFCC.csv: Asha_Bhosale
# 17-MFCC.csv: Indian_National_Anthem
# 74-MFCC.csv: Marathi_Lavni
# 06-MFCC.csv: Marathi_Lavni
# 40-MFCC.csv: Kishor_Kumar
# 58-MFCC.csv: Michael_Jackson
# 108-MFCC.csv: Indian_National_Anthem
# 44-MFCC.csv: Michael_Jackson
# 84-MFCC.csv: Asha_Bhosale
# 89-MFCC.csv: Asha_Bhosale
# 99-MFCC.csv: Asha_Bhosale
# 102-MFCC.csv: Asha_Bhosale
# 70-MFCC.csv: Marathi_Lavni
# 25-MFCC.csv: Asha_Bhosale
# 23-MFCC.csv: Asha_Bhosale
# 79-MFCC.csv: Asha_Bhosale
# 82-MFCC.csv: Asha_Bhosale
# 72-MFCC.csv: Marathi_Lavni
# 73-MFCC.csv: Marathi_Lavni
# 59-MFCC.csv: Kishor_Kumar
# 100-MFCC.csv: Asha_Bhosale
# 109-MFCC.csv: Marathi_Lavni
# 15-MFCC.csv: Marathi_Lavni
# 43-MFCC.csv: Marathi_Bhav_Geet
# 94-MFCC.csv: Asha_Bhosale
# 52-MFCC.csv: Marathi_Lavni
# 33-MFCC.csv: Asha_Bhosale
# 78-MFCC.csv: Michael_Jackson
# 55-MFCC.csv: Michael_Jackson
# 86-MFCC.csv: Michael_Jackson
